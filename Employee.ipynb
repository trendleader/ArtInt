# %% [markdown]
# <a href="https://colab.research.google.com/github/trendleader/ArtInt/blob/main/Employee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
employee=pd.read_csv('employeesfile.csv', encoding='latin1')

# %%
employee.head()
# Out:
#    BusinessEntityID FirstName    LastName                      JobTitle  \
# 0                84     Frank    Martinez  Production Technician - WC40
# 1                85     Brian   Goldstein  Production Technician - WC40
# 2                86      Ryan   Cornelsen  Production Technician - WC40
# 3                87  Cristian  Petculescu  Production Supervisor - WC10
# 4                88     Betsy     Stadick  Production Technician - WC10
#
#     BirthDate MaritalStatus Gender    HireDate  SalariedFlag  VacationHours  \
# 0    3/2/1952             M      M    2/5/2010             0             66
# 1  12/23/1970             S      M  12/11/2009             0             63
# 2   6/13/1972             M      M    1/5/2009             0             59
# 3   4/11/1984             M      M  12/22/2008             0             67
# 4  12/17/1966             S      F  12/18/2009             0             99
#
#    SickLeaveHours  Age AgeGroup  TenureWithCompany  \
# ...

# %%
# @title AgeGroup

from matplotlib import pyplot as plt
import seaborn as sns
employee.groupby('AgeGroup').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
